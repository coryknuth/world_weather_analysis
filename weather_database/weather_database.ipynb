# %%
# %matplotlib inline
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from datetime import datetime
import requests
import gmaps
from config import g_key
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 731

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]["description"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
      
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Current Description": city_description,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | phan rang
# City not found. Skipping...
# Processing Record 2 of Set 1 | pyapon
# Processing Record 3 of Set 1 | victoria
# Processing Record 4 of Set 1 | ancud
# Processing Record 5 of Set 1 | punta arenas
# Processing Record 6 of Set 1 | nikolskoye
# Processing Record 7 of Set 1 | ribeira grande
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | barrow
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | butaritari
# Processing Record 12 of Set 1 | yellowknife
# Processing Record 13 of Set 1 | arraial do cabo
# Processing Record 14 of Set 1 | altay
# Processing Record 15 of Set 1 | salamiyah
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | port alfred
# Processing Record 19 of Set 1 | iqaluit
# Processing Record 20 of Set 1 | kaitangata
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | dickinson
# Processing Record 23 of Set 1 | barcelona
# Processing Record 24 of Set 1 | bur gabo
# City not found. Skipping...
# Processing Record 25 of Set 1 | tasiilaq
# Processing Record 26 of Set 1 | busselton
# Processing Record 27 of Set 1 | ust-maya
# Processing Record 28 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | paramonga
# Processing Record 31 of Set 1 | aporawan
# City not found. Skipping...
# Processing Record 32 of Set 1 | camopi
# Processing Record 33 of Set 1 | bredasdorp
# Processing Record 34 of Set 1 | kapaa
# Processing Record 35 of Set 1 | kaeo
# Processing Record 36 of Set 1 | hambantota
# Processing Record 37 of Set 1 | konya
# Processing Record 38 of Set 1 | sri aman
# Processing Record 39 of Set 1 | cape town
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | tuktoyaktuk
# Processing Record 42 of Set 1 | tuatapere
# Processing Record 43 of Set 1 | marsh harbour
# Processing Record 44 of Set 1 | padang
# Processing Record 45 of Set 1 | avera
# Processing Record 46 of Set 1 | erenhot
# Processing Record 47 of Set 1 | hokitika
# Processing Record 48 of Set 1 | galle
# Processing Record 49 of Set 1 | jamestown
# Processing Record 50 of Set 1 | mikhaylovskoye
# Processing Record 1 of Set 2 | skjervoy
# Processing Record 2 of Set 2 | eyrarbakki
# Processing Record 3 of Set 2 | sitka
# Processing Record 4 of Set 2 | tecpatan
# Processing Record 5 of Set 2 | axim
# Processing Record 6 of Set 2 | penzance
# Processing Record 7 of Set 2 | ponta do sol
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | hof
# Processing Record 10 of Set 2 | japura
# Processing Record 11 of Set 2 | sharjah
# Processing Record 12 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 13 of Set 2 | xinzhou
# Processing Record 14 of Set 2 | lebu
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | dwarka
# Processing Record 17 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 2 | price
# Processing Record 19 of Set 2 | torbay
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | north platte
# Processing Record 22 of Set 2 | quatre cocos
# Processing Record 23 of Set 2 | motygino
# Processing Record 24 of Set 2 | teya
# Processing Record 25 of Set 2 | baiyin
# Processing Record 26 of Set 2 | port macquarie
# Processing Record 27 of Set 2 | constitucion
# Processing Record 28 of Set 2 | airai
# Processing Record 29 of Set 2 | senneterre
# Processing Record 30 of Set 2 | albany
# Processing Record 31 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 2 | tura
# Processing Record 33 of Set 2 | komsomolskiy
# Processing Record 34 of Set 2 | barahona
# Processing Record 35 of Set 2 | qaanaaq
# Processing Record 36 of Set 2 | itarema
# Processing Record 37 of Set 2 | pacifica
# Processing Record 38 of Set 2 | houma
# Processing Record 39 of Set 2 | mataura
# Processing Record 40 of Set 2 | kurayoshi
# Processing Record 41 of Set 2 | khatanga
# Processing Record 42 of Set 2 | saskylakh
# Processing Record 43 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 2 | kinango
# Processing Record 45 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 2 | karratha
# Processing Record 48 of Set 2 | semme
# Processing Record 49 of Set 2 | freeport
# Processing Record 50 of Set 2 | omsukchan
# Processing Record 1 of Set 3 | bethel
# Processing Record 2 of Set 3 | brownwood
# Processing Record 3 of Set 3 | georgetown
# Processing Record 4 of Set 3 | surt
# Processing Record 5 of Set 3 | poum
# Processing Record 6 of Set 3 | isangel
# Processing Record 7 of Set 3 | dukat
# Processing Record 8 of Set 3 | great falls
# Processing Record 9 of Set 3 | iranshahr
# Processing Record 10 of Set 3 | lukovetskiy
# Processing Record 11 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 3 | bathsheba
# Processing Record 13 of Set 3 | east london
# Processing Record 14 of Set 3 | vao
# Processing Record 15 of Set 3 | dolbeau
# City not found. Skipping...
# Processing Record 16 of Set 3 | ballina
# Processing Record 17 of Set 3 | kristiansund
# Processing Record 18 of Set 3 | urusha
# Processing Record 19 of Set 3 | kununurra
# Processing Record 20 of Set 3 | luderitz
# Processing Record 21 of Set 3 | goulburn
# Processing Record 22 of Set 3 | puerto ayora
# Processing Record 23 of Set 3 | blackwater
# Processing Record 24 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 3 | arrecife
# Processing Record 26 of Set 3 | carnarvon
# Processing Record 27 of Set 3 | laguna
# Processing Record 28 of Set 3 | oranjemund
# Processing Record 29 of Set 3 | esperance
# Processing Record 30 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 31 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 3 | tual
# Processing Record 33 of Set 3 | upernavik
# Processing Record 34 of Set 3 | chardara
# Processing Record 35 of Set 3 | muisne
# Processing Record 36 of Set 3 | colac
# Processing Record 37 of Set 3 | narsaq
# Processing Record 38 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 3 | chokurdakh
# Processing Record 40 of Set 3 | portland
# Processing Record 41 of Set 3 | phan thiet
# Processing Record 42 of Set 3 | houston
# Processing Record 43 of Set 3 | husavik
# Processing Record 44 of Set 3 | castro
# Processing Record 45 of Set 3 | muros
# Processing Record 46 of Set 3 | gannan
# Processing Record 47 of Set 3 | winslow
# Processing Record 48 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 3 | juneau
# Processing Record 50 of Set 3 | mahebourg
# Processing Record 1 of Set 4 | ponta delgada
# Processing Record 2 of Set 4 | ostrovnoy
# Processing Record 3 of Set 4 | jinchang
# Processing Record 4 of Set 4 | waddan
# Processing Record 5 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 4 | bluff
# Processing Record 7 of Set 4 | chuy
# Processing Record 8 of Set 4 | inta
# Processing Record 9 of Set 4 | moron
# Processing Record 10 of Set 4 | genhe
# Processing Record 11 of Set 4 | grindavik
# Processing Record 12 of Set 4 | norman wells
# Processing Record 13 of Set 4 | longyearbyen
# Processing Record 14 of Set 4 | mount gambier
# Processing Record 15 of Set 4 | shaoyang
# Processing Record 16 of Set 4 | petauke
# Processing Record 17 of Set 4 | mar del plata
# Processing Record 18 of Set 4 | vostok
# Processing Record 19 of Set 4 | inderborskiy
# City not found. Skipping...
# Processing Record 20 of Set 4 | port lincoln
# Processing Record 21 of Set 4 | cockburn town
# Processing Record 22 of Set 4 | san patricio
# Processing Record 23 of Set 4 | berlevag
# Processing Record 24 of Set 4 | huangmei
# Processing Record 25 of Set 4 | batticaloa
# Processing Record 26 of Set 4 | montijo
# Processing Record 27 of Set 4 | broome
# Processing Record 28 of Set 4 | adrar
# Processing Record 29 of Set 4 | misratah
# Processing Record 30 of Set 4 | pegnitz
# Processing Record 31 of Set 4 | fare
# Processing Record 32 of Set 4 | nome
# Processing Record 33 of Set 4 | avarua
# Processing Record 34 of Set 4 | puri
# Processing Record 35 of Set 4 | bambous virieux
# Processing Record 36 of Set 4 | tiksi
# Processing Record 37 of Set 4 | tateyama
# Processing Record 38 of Set 4 | aykhal
# Processing Record 39 of Set 4 | varaklani
# City not found. Skipping...
# Processing Record 40 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 4 | manta
# Processing Record 42 of Set 4 | olinda
# Processing Record 43 of Set 4 | cherskiy
# Processing Record 44 of Set 4 | bintulu
# Processing Record 45 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 4 | sembakung
# Processing Record 47 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 4 | saldanha
# Processing Record 49 of Set 4 | nizhnyaya tavda
# Processing Record 50 of Set 4 | havre-saint-pierre
# Processing Record 1 of Set 5 | porto-vecchio
# Processing Record 2 of Set 5 | kavieng
# Processing Record 3 of Set 5 | guerrero negro
# Processing Record 4 of Set 5 | dubai
# Processing Record 5 of Set 5 | alihe
# Processing Record 6 of Set 5 | nanortalik
# Processing Record 7 of Set 5 | progreso
# Processing Record 8 of Set 5 | port hedland
# Processing Record 9 of Set 5 | hithadhoo
# Processing Record 10 of Set 5 | dingle
# Processing Record 11 of Set 5 | ilheus
# Processing Record 12 of Set 5 | yaan
# Processing Record 13 of Set 5 | provideniya
# Processing Record 14 of Set 5 | vestmannaeyjar
# Processing Record 15 of Set 5 | cheyenne
# Processing Record 16 of Set 5 | inhambane
# Processing Record 17 of Set 5 | te anau
# Processing Record 18 of Set 5 | nantucket
# Processing Record 19 of Set 5 | shingu
# Processing Record 20 of Set 5 | yahotyn
# Processing Record 21 of Set 5 | kayerkan
# Processing Record 22 of Set 5 | thompson
# Processing Record 23 of Set 5 | tongchuan
# Processing Record 24 of Set 5 | fukue
# Processing Record 25 of Set 5 | bratsk
# Processing Record 26 of Set 5 | chibombo
# Processing Record 27 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 5 | eureka
# Processing Record 29 of Set 5 | praia
# Processing Record 30 of Set 5 | salalah
# Processing Record 31 of Set 5 | along
# Processing Record 32 of Set 5 | lerwick
# Processing Record 33 of Set 5 | basco
# Processing Record 34 of Set 5 | karakendzha
# City not found. Skipping...
# Processing Record 35 of Set 5 | novobirilyussy
# Processing Record 36 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 5 | manavalakurichi
# Processing Record 38 of Set 5 | lagoa
# Processing Record 39 of Set 5 | walvis bay
# Processing Record 40 of Set 5 | hasaki
# Processing Record 41 of Set 5 | sunyani
# Processing Record 42 of Set 5 | talnakh
# Processing Record 43 of Set 5 | talaya
# Processing Record 44 of Set 5 | hamilton
# Processing Record 45 of Set 5 | aklavik
# Processing Record 46 of Set 5 | sivac
# Processing Record 47 of Set 5 | sorland
# Processing Record 48 of Set 5 | coruripe
# Processing Record 49 of Set 5 | pisco
# Processing Record 50 of Set 5 | lubao
# Processing Record 1 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 2 of Set 6 | hisar
# Processing Record 3 of Set 6 | itoman
# Processing Record 4 of Set 6 | haines junction
# Processing Record 5 of Set 6 | bengkulu
# Processing Record 6 of Set 6 | kahului
# Processing Record 7 of Set 6 | codrington
# Processing Record 8 of Set 6 | ilulissat
# Processing Record 9 of Set 6 | cidreira
# Processing Record 10 of Set 6 | uwayl
# City not found. Skipping...
# Processing Record 11 of Set 6 | whitianga
# Processing Record 12 of Set 6 | batagay
# Processing Record 13 of Set 6 | sukagawa
# Processing Record 14 of Set 6 | kutum
# Processing Record 15 of Set 6 | tranas
# Processing Record 16 of Set 6 | nagato
# Processing Record 17 of Set 6 | labrea
# Processing Record 18 of Set 6 | belmonte
# Processing Record 19 of Set 6 | zeya
# Processing Record 20 of Set 6 | port hardy
# Processing Record 21 of Set 6 | archidona
# Processing Record 22 of Set 6 | utiroa
# City not found. Skipping...
# Processing Record 23 of Set 6 | fortuna
# Processing Record 24 of Set 6 | paysandu
# Processing Record 25 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 26 of Set 6 | nelson bay
# Processing Record 27 of Set 6 | atherton
# Processing Record 28 of Set 6 | haimen
# Processing Record 29 of Set 6 | neryungri
# Processing Record 30 of Set 6 | ngunguru
# Processing Record 31 of Set 6 | tautira
# Processing Record 32 of Set 6 | korla
# Processing Record 33 of Set 6 | broken hill
# Processing Record 34 of Set 6 | srednekolymsk
# Processing Record 35 of Set 6 | mantua
# Processing Record 36 of Set 6 | hofn
# Processing Record 37 of Set 6 | san andres
# Processing Record 38 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 39 of Set 6 | guiratinga
# Processing Record 40 of Set 6 | urumqi
# Processing Record 41 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 6 | buenaventura
# Processing Record 43 of Set 6 | sturgis
# Processing Record 44 of Set 6 | valparaiso
# Processing Record 45 of Set 6 | iskateley
# Processing Record 46 of Set 6 | zabol
# Processing Record 47 of Set 6 | road town
# Processing Record 48 of Set 6 | coquimbo
# Processing Record 49 of Set 6 | los llanos de aridane
# Processing Record 50 of Set 6 | saint anthony
# Processing Record 1 of Set 7 | bayangol
# Processing Record 2 of Set 7 | makat
# Processing Record 3 of Set 7 | alto longa
# Processing Record 4 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 7 | coihaique
# Processing Record 6 of Set 7 | strand
# Processing Record 7 of Set 7 | pathein
# Processing Record 8 of Set 7 | macaboboni
# City not found. Skipping...
# Processing Record 9 of Set 7 | cap malheureux
# Processing Record 10 of Set 7 | leningradskiy
# Processing Record 11 of Set 7 | juruti
# Processing Record 12 of Set 7 | la ronge
# Processing Record 13 of Set 7 | maputo
# Processing Record 14 of Set 7 | melnikovo
# Processing Record 15 of Set 7 | klaksvik
# Processing Record 16 of Set 7 | labuhan
# Processing Record 17 of Set 7 | michurinsk
# Processing Record 18 of Set 7 | tiarei
# Processing Record 19 of Set 7 | chapais
# Processing Record 20 of Set 7 | belgrade
# Processing Record 21 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 22 of Set 7 | vila velha
# Processing Record 23 of Set 7 | khaniotis
# Processing Record 24 of Set 7 | santa lucia
# Processing Record 25 of Set 7 | pekan
# Processing Record 26 of Set 7 | mattru
# Processing Record 27 of Set 7 | guilin
# Processing Record 28 of Set 7 | dikson
# Processing Record 29 of Set 7 | paamiut
# Processing Record 30 of Set 7 | burnie
# Processing Record 31 of Set 7 | liverpool
# Processing Record 32 of Set 7 | mujiayingzi
# Processing Record 33 of Set 7 | saint-philippe
# Processing Record 34 of Set 7 | kushima
# Processing Record 35 of Set 7 | golfito
# Processing Record 36 of Set 7 | saint george
# Processing Record 37 of Set 7 | kruisfontein
# Processing Record 38 of Set 7 | kyrylivka
# Processing Record 39 of Set 7 | lompoc
# Processing Record 40 of Set 7 | szczytno
# Processing Record 41 of Set 7 | verkhnevilyuysk
# Processing Record 42 of Set 7 | tarata
# Processing Record 43 of Set 7 | ahipara
# Processing Record 44 of Set 7 | igarapava
# Processing Record 45 of Set 7 | namatanai
# Processing Record 46 of Set 7 | monterey
# Processing Record 47 of Set 7 | pangnirtung
# Processing Record 48 of Set 7 | yar-sale
# Processing Record 49 of Set 7 | mayari
# City not found. Skipping...
# Processing Record 50 of Set 7 | singleton
# Processing Record 1 of Set 8 | verkhnyaya inta
# Processing Record 2 of Set 8 | muravlenko
# Processing Record 3 of Set 8 | flinders
# Processing Record 4 of Set 8 | novokayakent
# Processing Record 5 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 8 | bitung
# Processing Record 7 of Set 8 | arona
# Processing Record 8 of Set 8 | mount isa
# Processing Record 9 of Set 8 | beringovskiy
# Processing Record 10 of Set 8 | trairi
# Processing Record 11 of Set 8 | houlton
# Processing Record 12 of Set 8 | geraldton
# Processing Record 13 of Set 8 | praya
# Processing Record 14 of Set 8 | santo antonio do taua
# Processing Record 15 of Set 8 | bela
# Processing Record 16 of Set 8 | cairns
# Processing Record 17 of Set 8 | greifswald
# Processing Record 18 of Set 8 | semey
# Processing Record 19 of Set 8 | boende
# Processing Record 20 of Set 8 | kastamonu
# Processing Record 21 of Set 8 | chicama
# Processing Record 22 of Set 8 | ambilobe
# Processing Record 23 of Set 8 | khakhea
# Processing Record 24 of Set 8 | bako
# Processing Record 25 of Set 8 | le port
# Processing Record 26 of Set 8 | marathon
# Processing Record 27 of Set 8 | cabo san lucas
# Processing Record 28 of Set 8 | cortez
# Processing Record 29 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of Set 8 | yongchang
# Processing Record 31 of Set 8 | alta floresta
# Processing Record 32 of Set 8 | salinopolis
# Processing Record 33 of Set 8 | fort saint john
# City not found. Skipping...
# Processing Record 34 of Set 8 | balikpapan
# Processing Record 35 of Set 8 | alice springs
# Processing Record 36 of Set 8 | santiago
# Processing Record 37 of Set 8 | funadhoo
# Processing Record 38 of Set 8 | kloulklubed
# Processing Record 39 of Set 8 | saint-augustin
# Processing Record 40 of Set 8 | serenje
# Processing Record 41 of Set 8 | comodoro rivadavia
# Processing Record 42 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 43 of Set 8 | san cristobal
# Processing Record 44 of Set 8 | kitaibaraki
# Processing Record 45 of Set 8 | buala
# Processing Record 46 of Set 8 | asfi
# Processing Record 47 of Set 8 | salima
# Processing Record 48 of Set 8 | north myrtle beach
# Processing Record 49 of Set 8 | zhoukou
# Processing Record 50 of Set 8 | vardo
# Processing Record 1 of Set 9 | awjilah
# Processing Record 2 of Set 9 | imbituba
# Processing Record 3 of Set 9 | kiama
# Processing Record 4 of Set 9 | nosy varika
# Processing Record 5 of Set 9 | chingirlau
# Processing Record 6 of Set 9 | kaohsiung
# Processing Record 7 of Set 9 | qaqortoq
# Processing Record 8 of Set 9 | naze
# Processing Record 9 of Set 9 | shellbrook
# Processing Record 10 of Set 9 | burglengenfeld
# Processing Record 11 of Set 9 | thinadhoo
# Processing Record 12 of Set 9 | opuwo
# Processing Record 13 of Set 9 | chara
# Processing Record 14 of Set 9 | natal
# Processing Record 15 of Set 9 | arandis
# Processing Record 16 of Set 9 | benoy
# Processing Record 17 of Set 9 | inongo
# Processing Record 18 of Set 9 | touros
# Processing Record 19 of Set 9 | biak
# Processing Record 20 of Set 9 | gamba
# Processing Record 21 of Set 9 | lodja
# Processing Record 22 of Set 9 | jalu
# Processing Record 23 of Set 9 | nur
# Processing Record 24 of Set 9 | balashov
# Processing Record 25 of Set 9 | abha
# Processing Record 26 of Set 9 | port blair
# Processing Record 27 of Set 9 | bowen
# Processing Record 28 of Set 9 | colares
# Processing Record 29 of Set 9 | haapu
# City not found. Skipping...
# Processing Record 30 of Set 9 | scarborough
# Processing Record 31 of Set 9 | zhigansk
# Processing Record 32 of Set 9 | colesberg
# Processing Record 33 of Set 9 | tsagan aman
# Processing Record 34 of Set 9 | pevek
# Processing Record 35 of Set 9 | kaptanganj
# Processing Record 36 of Set 9 | yeppoon
# Processing Record 37 of Set 9 | bonavista
# Processing Record 38 of Set 9 | massaguet
# Processing Record 39 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 9 | wahiawa
# Processing Record 41 of Set 9 | noumea
# Processing Record 42 of Set 9 | mao
# Processing Record 43 of Set 9 | norton
# Processing Record 44 of Set 9 | tabuny
# Processing Record 45 of Set 9 | north bend
# Processing Record 46 of Set 9 | ha tinh
# Processing Record 47 of Set 9 | necochea
# Processing Record 48 of Set 9 | namibe
# Processing Record 49 of Set 9 | sorong
# Processing Record 50 of Set 9 | izumo
# Processing Record 1 of Set 10 | roswell
# Processing Record 2 of Set 10 | buraydah
# Processing Record 3 of Set 10 | kawalu
# Processing Record 4 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 10 | lasa
# Processing Record 6 of Set 10 | richards bay
# Processing Record 7 of Set 10 | wajir
# Processing Record 8 of Set 10 | mardin
# Processing Record 9 of Set 10 | high level
# Processing Record 10 of Set 10 | diamantino
# Processing Record 11 of Set 10 | atar
# Processing Record 12 of Set 10 | kampong thum
# Processing Record 13 of Set 10 | bulaevo
# Processing Record 14 of Set 10 | kamina
# Processing Record 15 of Set 10 | matay
# Processing Record 16 of Set 10 | shizunai
# Processing Record 17 of Set 10 | moree
# Processing Record 18 of Set 10 | kishi
# Processing Record 19 of Set 10 | itaquyry
# Processing Record 20 of Set 10 | shimoda
# Processing Record 21 of Set 10 | urdzhar
# City not found. Skipping...
# Processing Record 22 of Set 10 | tahoua
# Processing Record 23 of Set 10 | krasnoselkup
# Processing Record 24 of Set 10 | lanzhou
# Processing Record 25 of Set 10 | katsuura
# Processing Record 26 of Set 10 | marshfield
# Processing Record 27 of Set 10 | laurel
# Processing Record 28 of Set 10 | lavrentiya
# Processing Record 29 of Set 10 | ketchikan
# Processing Record 30 of Set 10 | fairbanks
# Processing Record 31 of Set 10 | cayenne
# Processing Record 32 of Set 10 | kushmurun
# Processing Record 33 of Set 10 | ayame
# Processing Record 34 of Set 10 | saurimo
# Processing Record 35 of Set 10 | sataua
# City not found. Skipping...
# Processing Record 36 of Set 10 | ocampo
# Processing Record 37 of Set 10 | taltal
# Processing Record 38 of Set 10 | teguldet
# Processing Record 39 of Set 10 | tabou
# Processing Record 40 of Set 10 | achisay
# City not found. Skipping...
# Processing Record 41 of Set 10 | micheweni
# Processing Record 42 of Set 10 | santa maria
# Processing Record 43 of Set 10 | nemuro
# Processing Record 44 of Set 10 | melville
# Processing Record 45 of Set 10 | perth
# Processing Record 46 of Set 10 | bodden town
# Processing Record 47 of Set 10 | lazaro cardenas
# Processing Record 48 of Set 10 | ukiah
# Processing Record 49 of Set 10 | carutapera
# Processing Record 50 of Set 10 | college
# Processing Record 1 of Set 11 | yarada
# Processing Record 2 of Set 11 | saint paul
# Processing Record 3 of Set 11 | ardakan
# Processing Record 4 of Set 11 | wilmington
# Processing Record 5 of Set 11 | stryn
# Processing Record 6 of Set 11 | praia da vitoria
# Processing Record 7 of Set 11 | brattleboro
# Processing Record 8 of Set 11 | accra
# Processing Record 9 of Set 11 | manggar
# Processing Record 10 of Set 11 | shumskiy
# Processing Record 11 of Set 11 | hervey bay
# Processing Record 12 of Set 11 | tiznit
# Processing Record 13 of Set 11 | general roca
# Processing Record 14 of Set 11 | roald
# Processing Record 15 of Set 11 | springville
# Processing Record 16 of Set 11 | aquiraz
# Processing Record 17 of Set 11 | tromso
# Processing Record 18 of Set 11 | bismarck
# Processing Record 19 of Set 11 | mount pleasant
# Processing Record 20 of Set 11 | ust-nera
# Processing Record 21 of Set 11 | nagar karnul
# Processing Record 22 of Set 11 | lusambo
# Processing Record 23 of Set 11 | rocha
# Processing Record 24 of Set 11 | axams
# Processing Record 25 of Set 11 | najran
# Processing Record 26 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 27 of Set 11 | viedma
# Processing Record 28 of Set 11 | buchanan
# Processing Record 29 of Set 11 | upington
# Processing Record 30 of Set 11 | atasu
# Processing Record 31 of Set 11 | mulchen
# Processing Record 32 of Set 11 | mecca
# Processing Record 33 of Set 11 | sopot
# Processing Record 34 of Set 11 | lieksa
# Processing Record 35 of Set 11 | valley city
# Processing Record 36 of Set 11 | bolobo
# Processing Record 37 of Set 11 | tanout
# Processing Record 38 of Set 11 | jakar
# Processing Record 39 of Set 11 | taitung
# Processing Record 40 of Set 11 | kon tum
# Processing Record 41 of Set 11 | novikovo
# Processing Record 42 of Set 11 | mvuma
# Processing Record 43 of Set 11 | bow island
# Processing Record 44 of Set 11 | kilosa
# Processing Record 45 of Set 11 | belaya gora
# Processing Record 46 of Set 11 | esmeraldas
# Processing Record 47 of Set 11 | juliaca
# Processing Record 48 of Set 11 | mullaitivu
# City not found. Skipping...
# Processing Record 49 of Set 11 | huancavelica
# Processing Record 50 of Set 11 | veraval
# Processing Record 1 of Set 12 | charters towers
# Processing Record 2 of Set 12 | hualmay
# Processing Record 3 of Set 12 | koshurnikovo
# Processing Record 4 of Set 12 | okandja
# City not found. Skipping...
# Processing Record 5 of Set 12 | ballymena
# Processing Record 6 of Set 12 | saint-pierre
# Processing Record 7 of Set 12 | moose factory
# Processing Record 8 of Set 12 | semnan
# Processing Record 9 of Set 12 | evensk
# Processing Record 10 of Set 12 | clyde river
# Processing Record 11 of Set 12 | nuristan
# Processing Record 12 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 13 of Set 12 | bandarbeyla
# Processing Record 14 of Set 12 | puke
# Processing Record 15 of Set 12 | kachiry
# Processing Record 16 of Set 12 | gairatganj
# Processing Record 17 of Set 12 | gubbi
# Processing Record 18 of Set 12 | kargopol
# Processing Record 19 of Set 12 | erdenet
# Processing Record 20 of Set 12 | temir
# Processing Record 21 of Set 12 | zurrieq
# Processing Record 22 of Set 12 | sechura
# Processing Record 23 of Set 12 | abbeville
# Processing Record 24 of Set 12 | soller
# Processing Record 25 of Set 12 | bay roberts
# Processing Record 26 of Set 12 | karpogory
# Processing Record 27 of Set 12 | redmond
# Processing Record 28 of Set 12 | marquette
# Processing Record 29 of Set 12 | pimentel
# Processing Record 30 of Set 12 | skegness
# Processing Record 31 of Set 12 | poso
# Processing Record 32 of Set 12 | williston
# Processing Record 33 of Set 12 | sonoita
# Processing Record 34 of Set 12 | beloha
# Processing Record 35 of Set 12 | berbera
# Processing Record 36 of Set 12 | sarrebourg
# Processing Record 37 of Set 12 | riyadh
# Processing Record 38 of Set 12 | kuntaur
# Processing Record 39 of Set 12 | cossato
# Processing Record 40 of Set 12 | cuyo
# Processing Record 41 of Set 12 | decatur
# Processing Record 42 of Set 12 | ucluelet
# Processing Record 43 of Set 12 | mangrol
# Processing Record 44 of Set 12 | sungai padi
# Processing Record 45 of Set 12 | davila
# Processing Record 46 of Set 12 | meulaboh
# Processing Record 47 of Set 12 | faanui
# Processing Record 48 of Set 12 | hovd
# Processing Record 49 of Set 12 | mundo nuevo
# Processing Record 50 of Set 12 | binzhou
# Processing Record 1 of Set 13 | rawson
# Processing Record 2 of Set 13 | kiunga
# Processing Record 3 of Set 13 | dori
# Processing Record 4 of Set 13 | amboasary
# Processing Record 5 of Set 13 | abu samrah
# Processing Record 6 of Set 13 | gurskoye
# City not found. Skipping...
# Processing Record 7 of Set 13 | westport
# Processing Record 8 of Set 13 | abu dhabi
# Processing Record 9 of Set 13 | vaxjo
# Processing Record 10 of Set 13 | nunoa
# Processing Record 11 of Set 13 | arraias
# Processing Record 12 of Set 13 | pacific grove
# Processing Record 13 of Set 13 | pangody
# Processing Record 14 of Set 13 | the valley
# Processing Record 15 of Set 13 | pekin
# Processing Record 16 of Set 13 | grand-lahou
# Processing Record 17 of Set 13 | chkalovsk
# Processing Record 18 of Set 13 | khani
# Processing Record 19 of Set 13 | dalhousie
# Processing Record 20 of Set 13 | san borja
# Processing Record 21 of Set 13 | mizan teferi
# Processing Record 22 of Set 13 | zhezkazgan
# Processing Record 23 of Set 13 | cambridge
# Processing Record 24 of Set 13 | samarai
# Processing Record 25 of Set 13 | banda aceh
# Processing Record 26 of Set 13 | cabedelo
# Processing Record 27 of Set 13 | baykit
# Processing Record 28 of Set 13 | verkhoyansk
# Processing Record 29 of Set 13 | garden city
# Processing Record 30 of Set 13 | mayo
# Processing Record 31 of Set 13 | hua hin
# Processing Record 32 of Set 13 | cascais
# Processing Record 33 of Set 13 | severo-kurilsk
# Processing Record 34 of Set 13 | grand centre
# City not found. Skipping...
# Processing Record 35 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 36 of Set 13 | phalodi
# Processing Record 37 of Set 13 | tumaco
# Processing Record 38 of Set 13 | hays
# Processing Record 39 of Set 13 | seydi
# Processing Record 40 of Set 13 | puerto colombia
# Processing Record 41 of Set 13 | saryg-sep
# Processing Record 42 of Set 13 | sao filipe
# Processing Record 43 of Set 13 | olafsvik
# Processing Record 44 of Set 13 | campbell river
# Processing Record 45 of Set 13 | svetlogorsk
# Processing Record 46 of Set 13 | barawe
# City not found. Skipping...
# Processing Record 47 of Set 13 | erdemli
# Processing Record 48 of Set 13 | tilichiki
# Processing Record 49 of Set 13 | kaka
# Processing Record 50 of Set 13 | mutsamudu
# City not found. Skipping...
# Processing Record 1 of Set 14 | kupang
# Processing Record 2 of Set 14 | dunedin
# Processing Record 3 of Set 14 | udachnyy
# Processing Record 4 of Set 14 | aksu
# Processing Record 5 of Set 14 | morehead
# Processing Record 6 of Set 14 | san quintin
# Processing Record 7 of Set 14 | pochutla
# Processing Record 8 of Set 14 | swiebodzice
# Processing Record 9 of Set 14 | puerto maldonado
# Processing Record 10 of Set 14 | pozo colorado
# Processing Record 11 of Set 14 | sarh
# Processing Record 12 of Set 14 | mnogovershinnyy
# Processing Record 13 of Set 14 | bethanien
# Processing Record 14 of Set 14 | khash
# Processing Record 15 of Set 14 | ilhabela
# Processing Record 16 of Set 14 | porto novo
# Processing Record 17 of Set 14 | thabazimbi
# Processing Record 18 of Set 14 | kenora
# Processing Record 19 of Set 14 | suntar
# Processing Record 20 of Set 14 | lima
# Processing Record 21 of Set 14 | honningsvag
# Processing Record 22 of Set 14 | posse
# Processing Record 23 of Set 14 | aasiaat
# Processing Record 24 of Set 14 | ames
# Processing Record 25 of Set 14 | novyy urengoy
# Processing Record 26 of Set 14 | anadyr
# Processing Record 27 of Set 14 | shu
# Processing Record 28 of Set 14 | jizan
# Processing Record 29 of Set 14 | nuevitas
# Processing Record 30 of Set 14 | houlung
# City not found. Skipping...
# Processing Record 31 of Set 14 | mugur-aksy
# Processing Record 32 of Set 14 | klyuchi
# Processing Record 33 of Set 14 | turayf
# Processing Record 34 of Set 14 | port keats
# Processing Record 35 of Set 14 | anahuac
# Processing Record 36 of Set 14 | lexington
# Processing Record 37 of Set 14 | mirnyy
# Processing Record 38 of Set 14 | ksenyevka
# City not found. Skipping...
# Processing Record 39 of Set 14 | chiredzi
# Processing Record 40 of Set 14 | harper
# Processing Record 41 of Set 14 | tsaratanana
# Processing Record 42 of Set 14 | kut chap
# Processing Record 43 of Set 14 | calvinia
# Processing Record 44 of Set 14 | mae sai
# Processing Record 45 of Set 14 | barra patuca
# Processing Record 46 of Set 14 | belyy gorodok
# Processing Record 47 of Set 14 | ambodifototra
# City not found. Skipping...
# Processing Record 48 of Set 14 | januaria
# Processing Record 49 of Set 14 | shalakusha
# Processing Record 50 of Set 14 | zheleznodorozhnyy
# Processing Record 1 of Set 15 | yangjiang
# Processing Record 2 of Set 15 | egvekinot
# Processing Record 3 of Set 15 | negombo
# Processing Record 4 of Set 15 | tapaua
# City not found. Skipping...
# Processing Record 5 of Set 15 | velasco ibarra
# Processing Record 6 of Set 15 | san policarpo
# Processing Record 7 of Set 15 | vagur
# Processing Record 8 of Set 15 | datong
# Processing Record 9 of Set 15 | hit
# Processing Record 10 of Set 15 | agva
# City not found. Skipping...
# Processing Record 11 of Set 15 | llanes
# Processing Record 12 of Set 15 | kirakira
# Processing Record 13 of Set 15 | beyneu
# Processing Record 14 of Set 15 | alofi
# Processing Record 15 of Set 15 | ayagoz
# Processing Record 16 of Set 15 | boa vista
# Processing Record 17 of Set 15 | maragogi
# Processing Record 18 of Set 15 | maniitsoq
# Processing Record 19 of Set 15 | mackay
# Processing Record 20 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 21 of Set 15 | corrales
# Processing Record 22 of Set 15 | san ramon
# Processing Record 23 of Set 15 | karaul
# City not found. Skipping...
# Processing Record 24 of Set 15 | muzhi
# Processing Record 25 of Set 15 | gao
# Processing Record 26 of Set 15 | mezhdurechensk
# Processing Record 27 of Set 15 | kitimat
# Processing Record 28 of Set 15 | dolores
# Processing Record 29 of Set 15 | brigantine
# Processing Record 30 of Set 15 | bam
# Processing Record 31 of Set 15 | lorengau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng   Current Description  Max Temp  \
# 0          Pyapon  16.2833   95.6833  heavy intensity rain     80.04
# 1        Victoria  22.2855  114.1577         broken clouds     90.21
# 2           Ancud -41.8697  -73.8203       overcast clouds     35.13
# 3    Punta Arenas -53.1500  -70.9167      scattered clouds     37.42
# 4      Nikolskoye  59.7035   30.7861             clear sky     71.40
# 5  Ribeira Grande  38.5167  -28.7000      scattered clouds     79.20
# 6         Ushuaia -54.8000  -68.3000      scattered clouds     35.26
# 7          Barrow  71.2906 -156.7887                  mist     37.42
# 8         Rikitea -23.1203 -134.9692             clear sky     68.63
# 9      Butaritari   3.0707  172.7902             clear sky     83.59
#
#    Humidity  Cloudiness  Wind Speed Country                 Date
# 0        88         100        9.51      MM  2021-07-24 13:19:05
# 1        81          78        1.01      HK  2021-07-24 13:19:05
# 2        82         100        5.26      CL  2021-07-24 13:19:06
# 3        87          40       13.80      CL  2021-07-24 13:19:06
# 4        32           9        7.38      RU  2021-07-24 13:19:06
# 5        69          40       19.57      PT  2021-07-24 13:19:07
# 6        80          40        5.75      AR  2021-07-24 13:18:07
# 7        93          90        8.05      US  2021-07-24 13:19:07
# 8        56           0        5.66      PF  2021-07-24 13:19:07
# 9        71           0       16.89      KI  2021-07-24 13:19:08

# %%
new_columns = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']

city_data_df = city_data_df[new_columns]

city_data_df.head(10)
# Out:
#              City Country                 Date      Lat       Lng  Max Temp  \
# 0          Pyapon      MM  2021-07-24 13:19:05  16.2833   95.6833     80.04
# 1        Victoria      HK  2021-07-24 13:19:05  22.2855  114.1577     90.21
# 2           Ancud      CL  2021-07-24 13:19:06 -41.8697  -73.8203     35.13
# 3    Punta Arenas      CL  2021-07-24 13:19:06 -53.1500  -70.9167     37.42
# 4      Nikolskoye      RU  2021-07-24 13:19:06  59.7035   30.7861     71.40
# 5  Ribeira Grande      PT  2021-07-24 13:19:07  38.5167  -28.7000     79.20
# 6         Ushuaia      AR  2021-07-24 13:18:07 -54.8000  -68.3000     35.26
# 7          Barrow      US  2021-07-24 13:19:07  71.2906 -156.7887     37.42
# 8         Rikitea      PF  2021-07-24 13:19:07 -23.1203 -134.9692     68.63
# 9      Butaritari      KI  2021-07-24 13:19:08   3.0707  172.7902     83.59
#
#    Humidity  Cloudiness  Wind Speed   Current Description
# 0        88         100        9.51  heavy intensity rain
# 1        81          78        1.01         broken clouds
# 2        82         100        5.26       overcast clouds
# 3        87          40       13.80      scattered clouds
# 4        32           9        7.38             clear sky
# 5        69          40       19.57      scattered clouds
# 6        80          40        5.75      scattered clouds
# 7        93          90        8.05                  mist
# 8        56           0        5.66             clear sky
# 9        71           0       16.89             clear sky

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
